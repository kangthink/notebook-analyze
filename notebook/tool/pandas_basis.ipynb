# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # 어떤 데이터를 가지고 분석하는가?
#
# - 각 유저별 영화에 대한 평가데이터
# - 유저가 있다.
# - 영화가 있다.
# - 유저, 영화, 평점에 관한 관계가 있다.

# %%
"""데이터를 가져오기

데이터 형식:
    누가 어떤 영화에 대해서 몇점을 언제 남겼는지에 대한 정보
"""

import sys
cols = ['user_id', 'item_id', 'rating', 'timestamp']
ratings = pd.read_csv('../../data/movieTweeting/ratings.dat', names=cols, sep='::', index_col=False)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
ratings.rating.sum()
# Out:
# 5756310

# %%
ratings.rating.mean()
# Out:
# 7.301468713572314

# %%
ratings.rating.var()
# Out:
# 3.440526638782201

# %%
ratings.rating.min()
# Out:
# 0

# %%
ratings.rating.max()
# Out:
# 10

# %%
"""데이터 정보 살펴보기

방식:
    각 데이터 별 갯수 확인하기
    해당 데이터 시각화하기
"""
rating_counts = ratings['rating'].value_counts()
sorted_counts = rating_countㅠs.sort_index()
sorted_counts
# Out:
# 0        230
# 1       9380
# 2       8110
# 3      13524
# 4      24805
# 5      58858
# 6     103191
# 7     177836
# 8     190570
# 9     110660
# 10     91213
# Name: rating, dtype: int64

# %%
plt.title('Movie rating')
plt.xlabel('rating')
plt.ylabel('count')
sorted_counts.plot(kind='bar', color='steelblue')

# %%
"""데이터 종합해서 살펴보기

"""
cols = ['movie_id', 'movie_title', 'genre']
movies = pd.read_csv('../../data/movieTweeting/movies.dat', names=cols, sep='::', index_col=False)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """

# %%
movies
# Out:
#        movie_id                                        movie_title  \
# 0             8      Edison Kinetoscopic Record of a Sneeze (1894)
# 1            10                La sortie des usines Lumière (1895)
# 2            12                      The Arrival of a Train (1896)
# 3            25  The Oxford and Cambridge University Boat Race ...
# 4            91                         Le manoir du diable (1896)
# 5           131                           Une nuit terrible (1896)
# 6           417                      Le voyage dans la lune (1902)
# 7           439                     The Great Train Robbery (1903)
# 8           443        Hiawatha, the Messiah of the Ojibway (1903)
# 9           628                    The Adventures of Dollie (1908)
# 10          833                          The Country Doctor (1909)
# 11         1223                                Frankenstein (1910)
# 12         1740                       The Lonedale Operator (1911)
# ...

# %%
is_drama = movies.genre == 'Crime|Drama'
is_drama
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 33619    False
# 33620    False
# 33621    False
# 33622    False
# 33623    False
# 33624    False
# 33625    False
# 33626    False
# 33627    False
# 33628    False
# 33629    False
# 33630    False
# 33631    False
# 33632    False
# 33633    False
# 33634    False
# 33635    False
# 33636    False
# 33637    False
# 33638    False
# 33639    False
# 33640    False
# 33641    False
# 33642    False
# 33643    False
# 33644    False
# 33645    False
# ...

# %%
drama = movies[is_drama]
drama
# Out:
#        movie_id                                        movie_title  \
# 16         2844       Fantômas - À l'ombre de la guillotine (1913)
# 237       20859                                     Escape! (1930)
# 251       21406                            Sono yo no tsuma (1930)
# 261       21739                                  La chienne (1931)
# 265       21785                      Daughter of the Dragon (1931)
# 288       22286                            The Public Enemy (1931)
# 289       22335                                Safe in Hell (1931)
# 293       22403                                 Smart Money (1931)
# 323       23054                       The Impassive Footman (1932)
# 366       23817                             Blondie Johnson (1933)
# 463       26246                        Crime and Punishment (1935)
# 474       26529                                The Informer (1935)
# 479       26743  Maria Marten, or The Murder in the Red Barn (1...
# ...

# %%
drama_ids = drama['movie_id']
drama_ids
# Out:
# 16          2844
# 237        20859
# 251        21406
# 261        21739
# 265        21785
# 288        22286
# 289        22335
# 293        22403
# 323        23054
# 366        23817
# 463        26246
# 474        26529
# 479        26743
# 541        28074
# 553        28346
# 557        28484
# 734        32609
# 980        36495
# 1119       38434
# 1173       39220
# 1181       39306
# 1285       40755
# 1429       42700
# 1438       42804
# 1564       44515
# 1627       45223
# 1727       46451
# 1729       46471
# 1824       47885
# 2009       50083
#           ...
# 30070    5078274
# 30193    5143704
# 30212    5156274
# 30245    5167632
# 30308    5207262
# 30450    5281018
# 30696    5477194
# 30732    5504810
# 30740    5513098
# 30789    5543604
# 30826    5580266
# 31184    5789976
# 31247    5837242
# 31288    5862902
# 31426    5957584
# 32185    6567012
# 32221    6603812
# 32234    6622902
# 32264    6675400
# 32312    6731636
# 32375    6802896
# ...
